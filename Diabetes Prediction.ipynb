# %%
import pandas as pd
import numpy as np
data1 = pd.read_csv("Dataset of Diabetes .csv")

# %%
data1
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
data1.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE            int64
# Urea         float64
# Cr             int64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
data1.tail(20)
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 980  179     834578      M   51   5.5   83    9.4   6.4  2.3  2.3  3.2   1.0
# 981  183     454316      M   65   5.0   97    7.0   4.3  4.3  1.4  1.5   2.0
# 982  184     454316      F   54   5.0   88    6.8   5.1  2.1  1.1  3.0   1.0
# 983  185     454316      M   64   8.8  106    8.5   5.9  2.1  1.2  4.0   1.2
# 984  187     454316      F   60   5.0   70    8.1   5.2  3.3  1.4  0.6   3.0
# 985  188     454316      F   75  10.3  113    8.6   4.2  1.6  0.9  2.6   0.7
# 986  189     454316      M   58   4.0   55    7.9   4.9  2.0  1.2  1.4   1.1
# 987  191     454316      M   55   5.4   62    6.8   5.3  2.0  1.0  3.5   0.9
# 988  192     454316      M   55   4.8   88   11.1   5.7  4.0  0.9  3.3   1.8
# 989  193     454316      M   62   6.3   82    6.7   5.3  2.0  1.0  3.5   0.9
# 990  194     454316      F   57   4.1   70    9.3   5.3  3.3  1.0  1.4   1.3
# ...

# %%
data1.shape
# Out:
# (1000, 14)

# %%
data1.head(10)
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224      F   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225      F   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6
# 7  421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8  670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 9  759      34230      F   32   3.6  28    4.0   3.8  2.0  2.4  3.8   1.0
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# 5  21.0     N
# 6  24.0     N
# 7  24.0     N
# ...

# %%
data1.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
data1["No_Pation"].count()
# Out:
# 1000

# %%
data1["No_Pation"].value_counts()
# Out:
# No_Pation
# 454316    19
# 856        2
# 87654      2
# 71741      2
# 34290      2
#           ..
# 34342      1
# 3275       1
# 34343      1
# 23973      1
# 24054      1
# Name: count, Length: 961, dtype: int64

# %%
data1.count()
# Out:
# ID           1000
# No_Pation    1000
# Gender       1000
# AGE          1000
# Urea         1000
# Cr           1000
# HbA1c        1000
# Chol         1000
# TG           1000
# HDL          1000
# LDL          1000
# VLDL         1000
# BMI          1000
# CLASS        1000
# dtype: int64

# %%
No_Pation_count=data1.groupby(["No_Pation","CLASS"]).size()

# %%
No_Pation_count
# Out:
# No_Pation  CLASS
# 123        Y        1
# 215        Y        1
# 234        Y        2
# 244        Y        1
# 252        P        1
#                    ..
# 8432454    Y        1
# 8785782    Y        1
# 33656789   Y        1
# 66467878   Y        1
# 75435657   N        1
# Length: 965, dtype: int64

# %%
class1_count=data1.groupby(["CLASS"]).size()
class1_count
# Out:
# CLASS
# N     102
# N       1
# P      53
# Y     840
# Y       4
# dtype: int64

# %%
Gender_count=data1.groupby(["Gender","CLASS"]).size()

# %%
Gender_count
# Out:
# Gender  CLASS
# F       N         64
#         P         17
#         Y        353
# M       N         38
#         N          1
#         P         36
#         Y        486
#         Y          4
# f       Y          1
# dtype: int64

# %%
#identify significant predictors
#algorithm in text to prdict diabetes based on the attributes.

# %%
AGE_count=data1.groupby(["AGE","CLASS"]).size()
AGE_count
# Out:
# AGE  CLASS
# 20   Y        1
# 25   N        1
# 26   N        1
#      Y        1
# 28   Y        3
#              ..
# 75   Y        2
# 76   Y        4
# 77   N        2
#      Y        2
# 79   Y        1
# Length: 96, dtype: int64

# %%
Urea_count=data1.groupby(["Urea","CLASS"]).size()
Urea_count
# Out:
# Urea  CLASS
# 0.5   Y        1
# 1.1   Y        1
# 1.2   Y        2
# 1.8   Y        3
# 1.9   Y        1
#               ..
# 22.0  N        1
#       Y        1
# 24.0  Y        3
# 26.4  Y        1
# 38.9  Y        1
# Length: 183, dtype: int64

# %%
Cr_count=data1.groupby(["Cr","CLASS"]).size()
Cr_count
# Out:
# Cr   CLASS
# 6    N        1
# 20   N        1
#      Y        1
# 22   Y        2
# 23   Y        4
#              ..
# 327  Y        1
# 344  P        1
# 370  Y        2
# 401  Y        3
# 800  Y        4
# Length: 182, dtype: int64

# %%
HbA1c_count=data1.groupby(["HbA1c","CLASS"]).size()
HbA1c_count
# Out:
# HbA1c  CLASS
# 0.9    N        4
# 2.0    Y        1
# 3.0    Y        1
# 3.7    N        1
#        Y        3
#                ..
# 14.7   Y        3
# 14.8   Y        1
# 15.0   Y        2
# 15.9   Y        1
# 16.0   Y        1
# Length: 135, dtype: int64

# %%
Chol_count=data1.groupby(["Chol","CLASS"]).size()
Chol_count
# Out:
# Chol  CLASS
# 0.0   N        1
# 0.5   N        1
# 0.6   Y        2
# 1.2   Y        1
# 2.0   N        1
#               ..
# 9.5   Y        2
# 9.7   Y        2
# 9.8   Y        2
# 9.9   Y        1
# 10.3  Y        1
# Length: 128, dtype: int64

# %%
TG_count=data1.groupby(["TG","CLASS"]).size()
TG_count
# Out:
# TG    CLASS
# 0.3   Y         2
# 0.5   Y         1
# 0.6   N         3
#       Y        11
# 0.7   N         6
#                ..
# 8.5   Y         1
# 8.7   Y         1
# 11.6  Y         1
# 12.7  Y         1
# 13.8  Y         1
# Length: 120, dtype: int64

# %%
HDL_count=data1.groupby(["HDL","CLASS"]).size()
HDL_count
# Out:
# HDL  CLASS
# 0.2  Y        1
# 0.4  Y        7
# 0.5  N        2
#      Y        5
# 0.6  N        1
#              ..
# 5.0  Y        1
# 6.3  Y        1
# 6.6  Y        2
# 9.0  Y        1
# 9.9  Y        1
# Length: 86, dtype: int64

# %%
LDL_count=data1.groupby(["LDL","CLASS"]).size()
LDL_count
# Out:
# LDL   CLASS
# 0.30  N        1
# 0.50  Y        2
# 0.60  Y        3
# 0.70  Y        2
# 0.75  Y        3
#               ..
# 6.40  Y        1
# 7.00  Y        1
# 7.50  Y        1
# 7.90  Y        2
# 9.90  Y        2
# Length: 123, dtype: int64

# %%
VLDL_count=data1.groupby(["VLDL","CLASS"]).size()
VLDL_count
# Out:
# VLDL  CLASS
# 0.1   Y         2
# 0.2   N         1
#       Y         4
# 0.3   N         6
#       Y        20
#                ..
# 27.2  Y         1
# 31.0  Y         1
# 31.8  Y         2
# 33.6  Y         1
# 35.0  Y         1
# Length: 92, dtype: int64

# %%
BMI_count=data1.groupby(["BMI","CLASS"]).size()
BMI_count
# Out:
# BMI    CLASS
# 19.00  N        2
#        P        4
#        Y        1
# 19.50  P        1
# 20.00  N        6
#                ..
# 40.50  Y        1
#        Y        1
# 43.25  Y        2
# 47.00  Y        2
# 47.75  Y        1
# Length: 86, dtype: int64

# %%
ID_count=data1.groupby(["ID","CLASS"]).size()
ID_count
# Out:
# ID   CLASS
# 1    Y        2
# 2    Y        2
# 3    Y        2
# 4    P        1
#      Y        1
#              ..
# 796  Y        1
# 797  Y        1
# 798  Y        1
# 799  N        1
# 800  Y        1
# Length: 861, dtype: int64

# %%
data1.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
pd.set_option("display.max_columns",None)
pd.set_option('display.max_rows', None)
data1
# Out:
#       ID  No_Pation Gender  AGE    Urea   Cr  HbA1c   Chol     TG   HDL   LDL  \
# 0    502      17975      F   50   4.700   46   4.90   4.20   0.90  2.40  1.40
# 1    735      34221      M   26   4.500   62   4.90   3.70   1.40  1.10  2.10
# 2    420      47975      F   50   4.700   46   4.90   4.20   0.90  2.40  1.40
# 3    680      87656      F   50   4.700   46   4.90   4.20   0.90  2.40  1.40
# 4    504      34223      M   33   7.100   46   4.90   4.90   1.00  0.80  2.00
# 5    634      34224      F   45   2.300   24   4.00   2.90   1.00  1.00  1.50
# 6    721      34225      F   50   2.000   50   4.00   3.60   1.30  0.90  2.10
# 7    421      34227      M   48   4.700   47   4.00   2.90   0.80  0.90  1.60
# 8    670      34229      M   43   2.600   67   4.00   3.80   0.90  2.40  3.70
# 9    759      34230      F   32   3.600   28   4.00   3.80   2.00  2.40  3.80
# 10   636      34231      F   31   4.400   55   4.20   3.60   0.70  1.70  1.60
# ...

# %%
data1['CLASS'].value_counts()
# Out:
# CLASS
# Y     840
# N     102
# P      53
# Y       4
# N       1
# Name: count, dtype: int64

# %%
data1.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
print('Null values in the dataset are: ',len(data1[data1.isnull().any(1)]))
data1.drop_duplicates(subset=None, keep='first', inplace=True)
data1.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print('Null values in the dataset are: ',len(data1[data1.isnull().any(1)]))
#       2 data1.drop_duplicates(subset=None, keep='first', inplace=True)
#       3 data1.shape
#
# TypeError: DataFrame.any() takes 1 positional argument but 2 were given

# %%
data1['Gender'].value_counts()
# Out:
# Gender
# M    565
# F    434
# f      1
# Name: count, dtype: int64

# %%
def classlablepredict(row):
    if row['AGE'] <49:
        age = 'N'
        
    elif row['AGE'] <51:
        age= 'P'
    else:
        age='Y'
    if row['Urea']<3.0:
        urea='N'
    elif row['Urea']<4.0:
        urea='P'
    else:
        urea='Y'
    if row['Cr']<25:
        cr='N'
    elif row['Cr']<30:
        cr='P'
    else:
        cr='Y'
    if row['HbA1c']<5.7:
        hb='N'
    elif row['HbA1c']<6.5:
        hb='P'
    else:
        hb='Y'
    if row['Chol']<2.0:
        ch='N'
    elif row['Chol']<2.5:
        ch='P'
    else:
        ch='Y'
    if row['TG']<1.0:
        tg='N'
    elif row['TG']<2.0:
        tg='P'
    else:
        tg='Y'
    if row['HDL']<0.6:
        hd='N'
    elif row['HDL']<1.6:
        hd='P'
    else:
        hd='Y'
    if row['LDL']<0.8:
        ld='N'
    elif row['LDL']<1.4:
        ld='P'
    else:
        ld='Y'
    if row['VLDL']<0.7:
        vl='N'
    elif row['VLDL']<1.2:
        vl='P'
    else:
        vl='Y'
    if row['BMI']<24.5:
        bmi='N'
    elif row['BMI']<26:
        bmi='P'
    else:
        bmi='Y'
    DS=0
    if age=='Y':
        DS=DS+1
    if urea=='Y':
        DS=DS+1
    if cr=='Y':
        DS=DS+1
    if hb=='Y':
        DS=DS+1
    if ch=='Y':
        DS=DS+1
    if tg=='Y':
        DS=DS+1
    if hd=='Y':
        DS=DS+1
    if ld=='Y':
        DS=DS+1
    if vl=='Y':
        DS=DS+1
    if bmi=='Y':
        DS=DS+1
    if DS>=6:
        DC='Y'
    elif DS>=5:
        DC='P'
    else:
        DC='N'
    return(DC)

# %%
data1.apply(lambda row: classlablepredict(row), axis = 1)
data1['class']=data1.apply(lambda row: classlablepredict(row),axis =1)

# %%
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
def truepositive(row):
    if row["CLASS"]=='Y' and row["class"]=='Y':
        tp=1
        return(tp)
    else:
        tp=0
        return(tp)

# %%
data1.apply(lambda row: truepositive(row), axis = 1)
data1['truepositive']=data1.apply(lambda row: truepositive(row),axis =1)

# %%
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
def truenegative(row):
    if row["CLASS"]=='N' and row["class"]=='N':
        tn=1
        return(tn)
    else:
        tn=0
        return(tn)

# %%
data1.apply(lambda row: truenegative(row), axis = 1)
data1['truenegative']=data1.apply(lambda row: truenegative(row),axis =1)
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
def falsepositive(row):
    if row["CLASS"]=='N' and row["class"]=='Y':
        fp=1
        return(fp)
    else:
        fp=0
        return(fp)

# %%
data1.apply(lambda row: falsepositive(row), axis = 1)
data1['falsepositive']=data1.apply(lambda row: falsepositive(row),axis =1)
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
def falsenegative(row):
    if row["CLASS"]=='Y' and row["class"]=='N':
        fn=1
        return(fn)
    else:
        fn=0
        return(fn)

# %%
data1.apply(lambda row: falsenegative(row), axis = 1)
data1['falsenegative']=data1.apply(lambda row: falsenegative(row),axis =1)
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
def trueoutcome(row):
    if row["CLASS"]==row["class"]:
        to=1
        return(to)
    else:
        to=0
        return(to)

# %%
data1.apply(lambda row: trueoutcome(row), axis = 1)
data1['true outcome']=data1.apply(lambda row: trueoutcome(row),axis =1)
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
def falsepositiveP(row):
    if (row["CLASS"]=='N' and row["class"]=='P') or (row["CLASS"]=='Y' and row["class"]=='P'):
        fpP=1
        return(fpP)
    else:
        fpP=0
        return(fpP)

# %%
data1.apply(lambda row: falsepositiveP(row), axis = 1)
data1['falsepositiveP']=data1.apply(lambda row: falsepositiveP(row),axis =1)
data1.head(40)
# Out:
#      ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7   47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6   67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6   28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4   55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
count_tp=data1["truepositive"].value_counts()[1]
count_tn=data1["truenegative"].value_counts()[1]
count_fp=data1["falsepositive"].value_counts()[1]
count_fn=data1["falsenegative"].value_counts()[1]
total = count_tp+count_tn+count_fp+count_fn
accuracy=(count_tp+count_tn)/total *100
print(accuracy)
# Out:
# 96.70454545454545
